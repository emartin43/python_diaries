# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '00b7a163-7d25-48ce-813a-f92f478096fd',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df = pd.json_normalize(data['data'])
    df['Timestamp'] = pd.to_datetime('now')
    df 
    
    if not os.path.isfile(r'/Users/evelynmartin/Python Diaries/small_projects/API.csv'):
        df.to_csv(r'/Users/evelynmartin/Python Diaries/small_projects/API.csv', header = 'column_names')
    else: df.to_csv(r'/Users/evelynmartin/Python Diaries/small_projects/API.csv', mode = 'a', header = False)

# %%
import pandas as pd

#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import os 
from time import time
from time import sleep 

for i in range(333):
    api_runner()
    print("API Runner completed")
    sleep(60) #sleep for 1 minute
exit()
# Out:
# /var/folders/br/g11f9tjd44q2lwq6n8gqf2hh0000gn/T/ipykernel_36364/1348254025.py:30: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['Timestamp'] = pd.to_datetime('now')
# API Runner completed
# /var/folders/br/g11f9tjd44q2lwq6n8gqf2hh0000gn/T/ipykernel_36364/1348254025.py:30: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['Timestamp'] = pd.to_datetime('now')
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [94], line 8
#       6     api_runner()
#       7     print("API Runner completed")
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'/Users/evelynmartin/Python Diaries/small_projects/API.csv')
df72
# Out:
#      Unnamed: 0    id         name symbol          slug  num_market_pairs  \
# 0             0     1      Bitcoin    BTC       bitcoin             10196
# 1             1  1027     Ethereum    ETH      ethereum              6806
# 2             2   825       Tether   USDT        tether             52317
# 3             3  1839          BNB    BNB           bnb              1306
# 4             4  3408     USD Coin   USDC      usd-coin             12101
# 5             5    52          XRP    XRP           xrp               940
# 6             6  2010      Cardano    ADA       cardano               775
# 7             7    74     Dogecoin   DOGE      dogecoin               698
# 8             8  5426       Solana    SOL        solana               458
# 9             9  3890      Polygon  MATIC       polygon               679
# 10           10  6636     Polkadot    DOT  polkadot-new               499
# 11           11     2     Litecoin    LTC      litecoin               909
# ...

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10196
# 1   1027     Ethereum    ETH      ethereum              6809
# 2    825       Tether   USDT        tether             52332
# 3   1839          BNB    BNB           bnb              1306
# 4   3408     USD Coin   USDC      usd-coin             12109
# 5     52          XRP    XRP           xrp               940
# 6   2010      Cardano    ADA       cardano               776
# 7     74     Dogecoin   DOGE      dogecoin               698
# 8   3890      Polygon  MATIC       polygon               680
# 9   5426       Solana    SOL        solana               458
# 10  6636     Polkadot    DOT  polkadot-new               499
# 11     2     Litecoin    LTC      litecoin               909
# 12  1958         TRON    TRX          tron               754
# 13  4687  Binance USD   BUSD   binance-usd              6682
# ...

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10196
# 1   1027     Ethereum    ETH      ethereum              6806
# 2    825       Tether   USDT        tether             52317
# 3   1839          BNB    BNB           bnb              1306
# 4   3408     USD Coin   USDC      usd-coin             12101
# 5     52          XRP    XRP           xrp               940
# 6   2010      Cardano    ADA       cardano               775
# 7     74     Dogecoin   DOGE      dogecoin               698
# 8   5426       Solana    SOL        solana               458
# 9   3890      Polygon  MATIC       polygon               679
# 10  6636     Polkadot    DOT  polkadot-new               499
# 11     2     Litecoin    LTC      litecoin               909
# 12  4687  Binance USD   BUSD   binance-usd              6680
# 13  1958         TRON    TRX          tron               754
# ...

# %%
# Now let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          1.08622                       0.94885
# Ethereum                         0.82785                       0.43789
# Tether                          -0.01461                      -0.00627
# BNB                              0.47877                       0.11078
# USD Coin                        -0.00263                       0.00721
# XRP                              0.48830                      -0.36943
# Cardano                          0.47089                      -0.93731
# Dogecoin                         0.31453                       0.04684
# Solana                           0.75981                      -0.04385
# Polygon                          0.54851                      -1.54570
# Polkadot                         0.54342                       0.30035
# Litecoin                         0.47905                      -0.04374
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      1.08622
#              quote.USD.percent_change_24h     0.94885
#              quote.USD.percent_change_7d      7.52499
#              quote.USD.percent_change_30d     3.72351
#              quote.USD.percent_change_60d    24.92159
#              quote.USD.percent_change_90d    27.23602
# Ethereum     quote.USD.percent_change_1h      0.82785
#              quote.USD.percent_change_24h     0.43789
#              quote.USD.percent_change_7d      2.92992
#              quote.USD.percent_change_30d     4.38133
#              quote.USD.percent_change_60d    15.95632
#              quote.USD.percent_change_90d    20.38612
# Tether       quote.USD.percent_change_1h     -0.01461
#              quote.USD.percent_change_24h    -0.00627
#              quote.USD.percent_change_7d      0.02480
#              quote.USD.percent_change_30d     0.05908
#              quote.USD.percent_change_60d     0.03057
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    1.08622
#             quote.USD.percent_change_24h   0.94885
#             quote.USD.percent_change_7d    7.52499
#             quote.USD.percent_change_30d   3.72351
#             quote.USD.percent_change_60d  24.92159
#             quote.USD.percent_change_90d  27.23602
# Ethereum    quote.USD.percent_change_1h    0.82785
#             quote.USD.percent_change_24h   0.43789
#             quote.USD.percent_change_7d    2.92992
#             quote.USD.percent_change_30d   4.38133
#             quote.USD.percent_change_60d  15.95632
#             quote.USD.percent_change_90d  20.38612
# Tether      quote.USD.percent_change_1h   -0.01461
#             quote.USD.percent_change_24h  -0.00627
#             quote.USD.percent_change_7d    0.02480
#             quote.USD.percent_change_30d   0.05908
#             quote.USD.percent_change_60d   0.03057
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h   1.08622
# 1       Bitcoin  quote.USD.percent_change_24h   0.94885
# 2       Bitcoin   quote.USD.percent_change_7d   7.52499
# 3       Bitcoin  quote.USD.percent_change_30d   3.72351
# 4       Bitcoin  quote.USD.percent_change_60d  24.92159
# 5       Bitcoin  quote.USD.percent_change_90d  27.23602
# 6      Ethereum   quote.USD.percent_change_1h   0.82785
# 7      Ethereum  quote.USD.percent_change_24h   0.43789
# 8      Ethereum   quote.USD.percent_change_7d   2.92992
# 9      Ethereum  quote.USD.percent_change_30d   4.38133
# 10     Ethereum  quote.USD.percent_change_60d  15.95632
# 11     Ethereum  quote.USD.percent_change_90d  20.38612
# 12       Tether   quote.USD.percent_change_1h  -0.01461
# 13       Tether  quote.USD.percent_change_24h  -0.00627
# 14       Tether   quote.USD.percent_change_7d   0.02480
# 15       Tether  quote.USD.percent_change_30d   0.05908
# ...

# %%
df7 = df6.rename(columns = {'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h   1.08622
# 1       Bitcoin  quote.USD.percent_change_24h   0.94885
# 2       Bitcoin   quote.USD.percent_change_7d   7.52499
# 3       Bitcoin  quote.USD.percent_change_30d   3.72351
# 4       Bitcoin  quote.USD.percent_change_60d  24.92159
# 5       Bitcoin  quote.USD.percent_change_90d  27.23602
# 6      Ethereum   quote.USD.percent_change_1h   0.82785
# 7      Ethereum  quote.USD.percent_change_24h   0.43789
# 8      Ethereum   quote.USD.percent_change_7d   2.92992
# 9      Ethereum  quote.USD.percent_change_30d   4.38133
# 10     Ethereum  quote.USD.percent_change_60d  15.95632
# 11     Ethereum  quote.USD.percent_change_90d  20.38612
# 12       Tether   quote.USD.percent_change_1h  -0.01461
# 13       Tether  quote.USD.percent_change_24h  -0.00627
# 14       Tether   quote.USD.percent_change_7d   0.02480
# 15       Tether  quote.USD.percent_change_30d   0.05908
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'], ['1h', '24h', '7d', '30d', '60d', '90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   1.08622
# 1       Bitcoin            24h   0.94885
# 2       Bitcoin             7d   7.52499
# 3       Bitcoin            30d   3.72351
# 4       Bitcoin            60d  24.92159
# 5       Bitcoin            90d  27.23602
# 6      Ethereum             1h   0.82785
# 7      Ethereum            24h   0.43789
# 8      Ethereum             7d   2.92992
# 9      Ethereum            30d   4.38133
# 10     Ethereum            60d  15.95632
# 11     Ethereum            90d  20.38612
# 12       Tether             1h  -0.01461
# 13       Tether            24h  -0.00627
# 14       Tether             7d   0.02480
# 15       Tether            30d   0.05908
# 16       Tether            60d   0.03057
# 17       Tether            90d   0.04430
# 18          BNB             1h   0.47877
# 19          BNB            24h   0.11078
# 20          BNB             7d  -2.01178
# 21          BNB            30d   1.50775
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y = 'values', hue ='name', data =df7, kind ='point')

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df72[['name','quote.USD.price','Timestamp']]
df10 = df10.query("name.str.contains('Bitcoin')")
df10
# Out:
#        name  quote.USD.price                   Timestamp
# 0   Bitcoin      29613.70342  2023-04-30 15:03:31.196668
# 15  Bitcoin      29631.33231  2023-04-30 15:04:31.484414
# 30  Bitcoin      28555.55123  2023-05-01 10:16:22.640699
# 45  Bitcoin      28559.30903  2023-05-01 10:17:22.982070
# 60  Bitcoin      28558.61168  2023-05-01 10:18:23.265333
# 75  Bitcoin      28558.61168  2023-05-01 10:19:19.312628
# 90  Bitcoin      28562.99526  2023-05-01 10:20:19.585595

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='Timestamp', y='quote.USD.price', data=df10)
plt.xticks(rotation=45)
plt.show()
